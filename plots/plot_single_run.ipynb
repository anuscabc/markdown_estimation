# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/market_100.csv')
df.head()
# Out:
#       price      cost  product  time      Car1      Car2    mshare   profits  \
# 0  2.948607  1.415698        1     1  5.543405  5.891322  0.063110  0.096742
# 1  3.971218  1.447384        2     1  5.278369  5.209202  0.059645  0.150534
# 2  5.279443  1.351142        3     1  5.424518  5.185328  0.040983  0.160995
# 3  3.148167  1.449088        4     1  5.844776  5.108377  0.031955  0.054294
# 4  3.040175  1.422723        5     1  5.004719  5.219697  0.139934  0.226336
#
#     markups
# 0  1.082794
# 1  1.743722
# 2  2.907394
# 3  1.172516
# 4  1.136871

# %%
for firm in df['product'].unique():
    df_firm = df[df['product'] == firm]
    # plt.plot(df_firm.time, df_firm.price)
    # plt.plot(df_firm.time, df_firm.cost)
    # plt.plot(df.time, df.markups)
    plt.plot(df_firm.time, df_firm.mshare)
plt.show()
