# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/market_integrates_100.csv')

# %%
df_grouped = df.groupby('product')
print(df_grouped)
# Look at the firm with bad product charactristics
group1 = df_grouped.get_group(2)
# Look at a firm with good product characteristics
group4 = df_grouped.get_group(4)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x124bdc2e0>

# %%
fig, [[ax1, ax2], [ax3, ax4]] = plt.subplots(2, 2)

for firm in df['product'].unique():
    df_firm = df[df['product'] == firm]
    ax1.plot(df_firm.time, df_firm.price)
    ax2.plot(df_firm.time, df_firm.marginal_cost)
    ax3.plot(df.time, df.markups)
    ax4.plot(df_firm.time, df_firm.mshare)

ax1.set_title('price')
ax2.set_title('cost')
ax3.set_title('markups')
ax4.set_title('market share')

plt.tight_layout()
plt.show()

# %%
fig, [[ax1, ax2], [ax3, ax4]] = plt.subplots(2, 2)
fig.suptitle(f'Firm with bad product characteristics')

ax1.plot(group1.time, group1.price)
ax2.plot(group1.time, group1.marginal_cost)
ax3.plot(group1.time, group1.markups)
ax4.plot(group1.time, group1.mshare)

ax1.set_title('price')
ax2.set_title('cost')
ax3.set_title('markups')
ax4.set_title('market share')

plt.tight_layout()
plt.show()

# %%
fig, [[ax1, ax2], [ax3, ax4]] = plt.subplots(2, 2)
fig.suptitle(f'Firm with good product characteristics')

ax1.plot(group4.time, group4.price, color='orange')
ax2.plot(group4.time, group4.marginal_cost, color='orange')
ax3.plot(group4.time, group4.markups, color='orange')
ax4.plot(group4.time, group4.mshare, color='orange')

ax1.set_title('price')
ax2.set_title('cost')
ax3.set_title('markups')
ax4.set_title('market share')

plt.tight_layout()
plt.show()

# %%
# df_cc = pd.read_csv('../data/market_constant_cost100.csv')
print(df.head(11))
df_grouped_cc = df.groupby('product')
# Look at the firm with bad product charactristics
group1_cc = df_grouped_cc.get_group(1)
# Look at a firm with good product characteristics
group4_cc = df_grouped_cc.get_group(5)
# Out:
#     time  product  characteristic1  characteristic2     price  marginal_cost  \
# 0      1        1         5.433865         5.433865  2.741721       0.781560
# 1      1        2         5.907737         5.907737  2.324290       0.532653
# 2      1        3         5.943911         5.943911  2.266723       0.498882
# 3      1        4         5.329441         5.329441  2.883364       0.867357
# 4      1        5         5.083033         5.083033  3.019253       0.949951
# 5      1        6         5.360283         5.360283  2.849370       0.846725
# 6      1        7         5.958183         5.958183  2.337551       0.540631
# 7      1        8         5.184745         5.184745  2.737584       0.778648
# 8      1        9         5.223118         5.223118  2.725636       0.771490
# 9      1       10         5.019838         5.019838  3.208799       1.066411
# 10     2        1         5.433865         5.433865  9.660983       5.649863
#
#       mshare   profits   markups  e_quantity   capital  investment  \
# 0   0.095718  0.187623  2.508012   47.858965  0.912243    0.136382
# 1   0.081786  0.146531  3.363609   40.893002  1.001140    0.147558
# 2   0.082055  0.145061  3.543601   41.027677  0.929392    0.140959
# 3   0.096926  0.195404  2.324309   48.463187  0.874897    0.129858
# 4   0.110474  0.228604  2.178324   55.237084  0.997609    0.150819
# 5   0.096172  0.192598  2.365166   48.085855  1.006210    0.145584
# 6   0.077975  0.140115  3.323749   38.987410  1.007378    0.144488
# 7   0.117074  0.229340  2.515819   58.536968  1.182771    0.185033
# 8   0.114228  0.223217  2.532948   57.113793  0.991660    0.158595
# 9   0.106233  0.227591  2.008970   53.116266  0.894581    0.132418
# 10  0.087736  0.351921  0.709950   43.868113  1.003014    0.081654
#
#     productivity      labor_q      labor_o      mu_o      mu_q
# 0       0.995023   638.060438  3189.641619 -0.382928  2.084722
# 1       0.973903   326.206134  2682.544636 -0.468524  3.370573
# 2       1.016676   340.163618  2554.046883 -0.453818  3.100895
# 3       0.984261   760.258771  3237.153371 -0.352500  1.757029
# 4       1.011803   789.729852  4100.395199 -0.389907  2.167692
# 5       0.946857   605.461521  3470.009322 -0.407720  2.394461
# 6       0.934300   312.929585  2571.602601 -0.468415  3.368477
# 7       1.064404   540.507246  4556.598697 -0.472469  3.447208
# 8       1.099291   668.736537  3990.558057 -0.414851  2.491765
# 9       0.980225   993.060431  3834.152735 -0.333206  1.574457
# 10      0.314084  3702.103762  8014.854867 -0.206831  0.717169

# %%
fig, [[ax1, ax2], [ax3, ax4], [ax5, ax6]] = plt.subplots(3, 2)
fig.suptitle(f'Firm with bad product characteristics')

ax1.plot(group1_cc.time, group1_cc.price)
ax2.plot(group1_cc.time, group1_cc.productivity)
ax3.plot(group1_cc.time, group1_cc.markups)
ax4.plot(group1_cc.time, group1_cc.mshare)
ax5.plot(group1_cc.time, group1_cc.capital)
ax6.plot(group1_cc.time, group1_cc.marginal_cost)

ax1.set_title('price')
ax2.set_title('productivity')
ax3.set_title('markups')
ax4.set_title('market share')
ax5.set_title('capital')
ax6.set_title('costs')

plt.tight_layout()
plt.show()

# %%
fig, [[ax1, ax2], [ax3, ax4], [ax5, ax6]] = plt.subplots(3, 2)
fig.suptitle(f'Firm with good product characteristicsimage.png')

ax1.plot(group4_cc.time, group4_cc.price, color='orange')
ax2.plot(group4_cc.time, group4_cc.productivity, color='orange')
ax3.plot(group4_cc.time, group4_cc.markups, color='orange')
ax4.plot(group4_cc.time, group4_cc.mshare, color='orange')
ax5.plot(group4_cc.time, group4_cc.capital, color='orange')
ax6.plot(group4_cc.time, group4_cc.marginal_cost, color='orange')

ax1.set_title('price')
ax2.set_title('productivity')
ax3.set_title('markups')
ax4.set_title('market share')
ax5.set_title('capital')
ax6.set_title('costs')

plt.tight_layout()
plt.show()

# %%
fig, [[ax1, ax2], [ax3, ax4], [ax5, ax6]] = plt.subplots(3, 2)

for firm in df_cc['product'].unique():
    df_firm_cc = df_cc[df_cc['product'] == firm]
    ax1.plot(df_firm_cc.time, df_firm_cc.price)
    ax2.plot(df_firm_cc.time, df_firm_cc.shocks)
    ax3.plot(df_firm_cc.time, df_firm_cc.markups)
    ax4.plot(df_firm_cc.time, df_firm_cc.mshare)
    ax5.plot(df_firm_cc.time, df_firm_cc.profits)
    ax6.plot(df_firm_cc.time, df_firm_cc.cost)


ax1.set_title('price')
ax2.set_title('shocks')
ax3.set_title('markups')
ax4.set_title('market share')
ax5.set_title('profits')
ax6.set_title('cost')


plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/popovici/Desktop/Thesis/markdown_estimation/plots/plot_single_run.ipynb Cell 10 in 3
#       <a href='vscode-notebook-cell:/Users/popovici/Desktop/Thesis/markdown_estimation/plots/plot_single_run.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> fig, [[ax1, ax2], [ax3, ax4], [ax5, ax6]] = plt.subplots(3, 2)
# ----> <a href='vscode-notebook-cell:/Users/popovici/Desktop/Thesis/markdown_estimation/plots/plot_single_run.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> for firm in df_cc['product'].unique():
#       <a href='vscode-notebook-cell:/Users/popovici/Desktop/Thesis/markdown_estimation/plots/plot_single_run.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a>     df_firm_cc = df_cc[df_cc['product'] == firm]
#       <a href='vscode-notebook-cell:/Users/popovici/Desktop/Thesis/markdown_estimation/plots/plot_single_run.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a>     ax1.plot(df_firm_cc.time, df_firm_cc.price)
#
# NameError: name 'df_cc' is not defined
