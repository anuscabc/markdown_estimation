# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/market_100.csv')
df.head()
# Out:
#       price      cost  product  time      Car1      Car2    mshare   profits  \
# 0  1.992243  1.386685        1     1  5.543405  5.891322  0.075614  0.045789
# 1  1.963853  1.358202        2     1  5.278369  5.209202  0.111008  0.067232
# 2  1.948191  1.342556        3     1  5.424518  5.185328  0.106646  0.064588
# 3  2.005351  1.399770        4     1  5.844776  5.108377  0.080498  0.048748
# 4  1.951665  1.345970        5     1  5.004719  5.219697  0.129460  0.078413
#
#     markups
# 0  0.436695
# 1  0.445921
# 2  0.451105
# 3  0.432629
# 4  0.450006

# %%
fig, [[ax1, ax2], [ax3, ax4]] = plt.subplots(2, 2)

for firm in df['product'].unique():
    df_firm = df[df['product'] == firm]
    ax1.plot(df_firm.time, df_firm.price)
    ax2.plot(df_firm.time, df_firm.cost)
    ax3.plot(df.time, df.markups)
    ax4.plot(df_firm.time, df_firm.mshare)

ax1.set_title('price')
ax2.set_title('cost')
ax3.set_title('markups')
ax4.set_title('market share')

plt.tight_layout()
plt.show()
