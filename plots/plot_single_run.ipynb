# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/market_100.csv')
df.head()
# Out:
#       price      cost  product  time      Car1      Car2    mshare   profits  \
# 0  3.695253  1.415698        1     1  5.543405  5.891322  0.078804  0.179638
# 1  3.756714  1.447384        2     1  5.278369  5.209202  0.107499  0.248250
# 2  3.576872  1.351142        3     1  5.424518  5.185328  0.108904  0.242391
# 3  3.758122  1.449088        4     1  5.844776  5.108377  0.083422  0.192625
# 4  3.711281  1.422723        5     1  5.004719  5.219697  0.125313  0.286786
#
#     markups
# 0  1.610199
# 1  1.595521
# 2  1.647296
# 3  1.593439
# 4  1.608576

# %%
for firm in df['product'].unique():
    df_firm = df[df['product'] == firm]
    # plt.plot(df_firm.time, df_firm.price)
    # plt.plot(df_firm.time, df_firm.cost)
    plt.plot(df.time, df.markups)
    # plt.plot(df_firm.time, df_firm.mshare)
plt.show()
